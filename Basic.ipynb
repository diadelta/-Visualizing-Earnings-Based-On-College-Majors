# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna(axis=0)
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title="Sample vs. Median")

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Sample_size vs. Unemployment_rate")

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Full_time vs. Median")

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter", title="Men vs. Median")

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Women vs. Median")

# %%
recent_grads
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %% [markdown]
# ## Do students in more popular majors make more money?

# %%
recent_grads_sorted = recent_grads.sort_values("Total")[["Total", "Major", "Median"]]
recent_grads_sorted
# Out:
#         Total                                              Major  Median
# 73      124.0                              MILITARY TECHNOLOGIES   40000
# 52      609.0                   MATHEMATICS AND COMPUTER SCIENCE   42000
# 112     685.0                                       SOIL SCIENCE   35000
# 33      720.0             GEOLOGICAL AND GEOPHYSICAL ENGINEERING   50000
# 1       756.0                     MINING AND MINERAL ENGINEERING   75000
# 120     804.0         EDUCATIONAL ADMINISTRATION AND SUPERVISION   34000
# 55      818.0                          SCHOOL STUDENT COUNSELING   41000
# 2       856.0                          METALLURGICAL ENGINEERING   73000
# 172    1098.0                                    LIBRARY SCIENCE   22000
# 19     1148.0                                    COURT REPORTING   54000
# 3      1258.0          NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000
# 83     1329.0                                             BOTANY   37000
# ...

# %%
ax = recent_grads_sorted.plot(x="Total", y="Median", kind="bar", figsize=(40,10))
ax.set_xticklabels(recent_grads_sorted["Major"], rotation=90)
ax.set_xlabel("Major")
ax.set_ylabel("Median")
ax.set_title("Major vs. Median")
# Out:
# Text(0.5,1,'Major vs. Median')

# %%
from numpy import arange
fig = plt.figure(figsize=(10,80))
for i in range(4):
    ax = fig.add_subplot(4,1,i+1)
    position = arange(43) 
    width = recent_grads_sorted["Median"].iloc[i*43:(i+1)*43]
    ax.barh(position, width)
    ax.set_yticks(position)
    ax.set_yticklabels(recent_grads_sorted["Major"].iloc[i*43:(i+1)*43])

# %% [markdown]
# Students who study in more popular majors don't generate more money in their working field.

# %% [markdown]
# ## Do students that majored in subjects that were majority female make more money?

# %%
recent_grads_cols = recent_grads[["Men", "Women", "Median"]]
recent_grads_cols = recent_grads_cols.reset_index()
recent_grads_cols
# Out:
#      index      Men     Women  Median
# 0        0   2057.0     282.0  110000
# 1        1    679.0      77.0   75000
# 2        2    725.0     131.0   73000
# 3        3   1123.0     135.0   70000
# 4        4  21239.0   11021.0   65000
# 5        5   2200.0     373.0   65000
# 6        6   2110.0    1667.0   62000
# 7        7    832.0     960.0   62000
# 8        8  80320.0   10907.0   60000
# 9        9  65511.0   16016.0   60000
# 10      10  33258.0    8284.0   60000
# 11      11  12953.0    2105.0   60000
# 12      12   8407.0    6548.0   60000
# 13      13   2949.0    1330.0   60000
# 14      14   3526.0     795.0   58000
# 15      15   6062.0    2863.0   57100
# 16      16  12453.0    6515.0   57000
# 17      17  45683.0   15469.0   56000
# 18      18   1835.0     990.0   54000
# 19      19    877.0     271.0   54000
# 20      20  99743.0   28576.0   53000
# 21      22   8181.0    3384.0   52000
# 22      23   2020.0     973.0   52000
# 23      24  13496.0    5217.0   51000
# ...

# %%
women_num = recent_grads_cols["Women"].values
men_num = recent_grads_cols["Men"].values

w_median = []
m_median = []

for i in range(0,len(women_num)):
    if women_num[i] > men_num[i]:
        w_median.append(recent_grads_cols.loc[i]["Median"])
    else:
        m_median.append(recent_grads_cols.loc[i]["Median"])

# %%
m_median_avg = sum(m_median)/len(m_median)
m_median_avg
# Out:
# 46988.15789473684

# %%
w_median_avg = sum(w_median)/len(w_median)
w_median_avg
# Out:
# 34605.208333333336

# %% [markdown]
# Subjects which are majority female don't offer higher salary.

# %% [markdown]
# # Is there any link between the number of full-time employees and median salary?

# %%
ax = recent_grads.plot(x="Full_time", y="Median", kind="scatter")

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]
cols
# Out:
# ['Sample_size',
#  'Median',
#  'Employed',
#  'Full_time',
#  'ShareWomen',
#  'Unemployment_rate',
#  'Men',
#  'Women']

# %%
fig, ax = plt.subplots()
ax.hist(recent_grads["Sample_size"], bins=20)
x = [ 2.00000000e+00,   2.12500000e+02,   4.23000000e+02,
      6.33500000e+02,   8.44000000e+02,   1.05450000e+03,
      1.26500000e+03,   1.47550000e+03,   1.68600000e+03,
      1.89650000e+03,   2.10700000e+03,   2.31750000e+03,
      2.52800000e+03,   2.73850000e+03,   2.94900000e+03,
      3.15950000e+03,   3.37000000e+03,   3.58050000e+03,
      3.79100000e+03,   4.00150000e+03,   4.21200000e+03]
ax.set_xticks(x)
ax.set_xticklabels(x, rotation=90)
ax.set_xlabel("Sample_size")
ax.set_ylabel("Frequency")
ax.set_title("Sample_size column Distribution")
# Out:
# Text(0.5,1,'Sample_size column Distribution')

# %%
fig, ax = plt.subplots()
ax.hist(recent_grads["Median"], bins=20, range=(20000,80000))
ax.set_xlabel("Median")
ax.set_ylabel("Frequency")
ax.set_title("Median column Distribution")
# Out:
# Text(0.5,1,'Median column Distribution')

# %%
ax = recent_grads["Employed"].plot(kind="hist", bins=20, rot=90)
x = [0., 15396.65, 30793.3, 46189.95, 61586.6, 76983.25, 92379.9, 107776.55, 123173.2, 138569.85, 153966.5, 169363.15, 184759.8,  200156.45,  215553.1 ,
     230949.75,  246346.4 ,  261743.05,  277139.7 ,  292536.35,  307933.]
ax.set_xticks(x)
ax.set_xlabel("Employed")
ax.set_title("Employed column Distribution")
# Out:
# Text(0.5,1,'Employed column Distribution')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.hist(recent_grads["Full_time"], bins=20)
x = [ 1.11000000e+02,   1.26824500e+04,   2.52539000e+04,
      3.78253500e+04,   5.03968000e+04,   6.29682500e+04,
      7.55397000e+04,   8.81111500e+04,   1.00682600e+05,
      1.13254050e+05,   1.25825500e+05,   1.38396950e+05,
      1.50968400e+05,   1.63539850e+05,   1.76111300e+05,
      1.88682750e+05,   2.01254200e+05,   2.13825650e+05,
      2.26397100e+05,   2.38968550e+05,   2.51540000e+05]
ax.set_xticks(x)
ax.set_xticklabels(x, rotation=90)
ax.set_xlabel("Full_time")
ax.set_ylabel("Frquency")
ax.set_title("Full_time column Distribution")
# Out:
# Text(0.5,1,'Full_time column Distribution')

# %%
fig, ax = plt.subplots()
ax.hist(recent_grads["ShareWomen"],bins=10)
x = [0.        ,  0.09689537,  0.19379074,  0.2906861 ,  0.38758147,
     0.48447684,  0.58137221,  0.67826758,  0.77516295,  0.87205831,
     0.96895368]
ax.set_xticks(x)
ax.set_xticklabels(x, rotation=90)
ax.set_xlabel("ShareWomen")
ax.set_ylabel("Frequency")
ax.set_title("ShareWomen column Distribution")
# Out:
# Text(0.5,1,'ShareWomen column Distribution')

# %%
fig = plt.figure(figsize=(10,20))
for i in range(5,8):
    ax = fig.add_subplot(3,1,i-4)
    ax.hist(recent_grads[cols[i]], bins=20)
    ax.set_xlabel(cols[i])
    ax.set_ylabel("Frequency")
    ax.set_title(cols[i] +" column Distribution")

# %% [markdown]
# # What percent of majors are predominantly male? Predominantly female?

# %%
cols_sex = recent_grads[["Men", "Women"]]
cols_sex
# Out:
#          Men     Women
# 0     2057.0     282.0
# 1      679.0      77.0
# 2      725.0     131.0
# 3     1123.0     135.0
# 4    21239.0   11021.0
# 5     2200.0     373.0
# 6     2110.0    1667.0
# 7      832.0     960.0
# 8    80320.0   10907.0
# 9    65511.0   16016.0
# 10   33258.0    8284.0
# 11   12953.0    2105.0
# 12    8407.0    6548.0
# 13    2949.0    1330.0
# 14    3526.0     795.0
# 15    6062.0    2863.0
# 16   12453.0    6515.0
# 17   45683.0   15469.0
# 18    1835.0     990.0
# 19     877.0     271.0
# 20   99743.0   28576.0
# 22    8181.0    3384.0
# 23    2020.0     973.0
# 24   13496.0    5217.0
# 25   41081.0   12072.0
# 26   16820.0    1678.0
# 27    7921.0    3811.0
# 28    7398.0    1735.0
# 29    2639.0    3339.0
# 30    2662.0    1385.0
# ..       ...       ...
# 143   4897.0    2519.0
# 144   2049.0    4434.0
# 145  86648.0  307087.0
# 146  29909.0   30724.0
# 147  15670.0   12543.0
# 148   3240.0   17790.0
# 149  24786.0   49654.0
# 150   5166.0   52835.0
# ...

# %%
m_count = 0
w_count = 0

for i in range(172):
    if cols_sex["Men"].iloc[i] > cols_sex["Women"].iloc[i]:
        m_count += 1
    else:
        w_count += 1
male_pert = round(m_count/cols_sex.shape[0]*100, 2)
male_pert
# Out:
# 44.19
